# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})

        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | leningradskiy
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | goderich
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | bokovskaya
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | el alto
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | dubbo
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | codrington
# Processing Record 15 of Set 1 | half moon bay
# Processing Record 16 of Set 1 | osa
# Processing Record 17 of Set 1 | hervey bay
# Processing Record 18 of Set 1 | copiapo
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | zhigansk
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | ewo
# Processing Record 23 of Set 1 | otjiwarongo
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | whitehorse
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | marienburg
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | sioux lookout
# Processing Record 33 of Set 1 | japura
# Processing Record 34 of Set 1 | verkhnyaya inta
# Processing Record 35 of Set 1 | moss point
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | coihaique
# Processing Record 38 of Set 1 | fort saint james
# Processing Record 39 of Set 1 | vetralla
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | nanortalik
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | chipping sodbury
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | novo horizonte
# Processing Record 46 of Set 1 | byron bay
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | vardo
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | muzhi
# Processing Record 3 of Set 2 | katsuura
# Processing Record 4 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 2 | saskylakh
# Processing Record 6 of Set 2 | shingu
# Processing Record 7 of Set 2 | coquimbo
# Processing Record 8 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 2 | san matias
# Processing Record 10 of Set 2 | ingham
# Processing Record 11 of Set 2 | snasa
# Processing Record 12 of Set 2 | ozernovskiy
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | skjervoy
# Processing Record 15 of Set 2 | isangel
# Processing Record 16 of Set 2 | kemijarvi
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | san patricio
# Processing Record 19 of Set 2 | seoul
# Processing Record 20 of Set 2 | cap malheureux
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | tashtyp
# Processing Record 23 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | matadi
# Processing Record 26 of Set 2 | kenai
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | kavaratti
# Processing Record 29 of Set 2 | emba
# Processing Record 30 of Set 2 | laramie
# Processing Record 31 of Set 2 | swan river
# Processing Record 32 of Set 2 | bushehr
# Processing Record 33 of Set 2 | sao domingos
# Processing Record 34 of Set 2 | estelle
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | jefferson city
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | maragogi
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | cayenne
# Processing Record 44 of Set 2 | patiya
# Processing Record 45 of Set 2 | suraabad
# Processing Record 46 of Set 2 | puerto del rosario
# Processing Record 47 of Set 2 | tobolsk
# Processing Record 48 of Set 2 | pontes e lacerda
# Processing Record 49 of Set 2 | dunedin
# Processing Record 50 of Set 2 | teguldet
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | okhotsk
# Processing Record 3 of Set 3 | altay
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | bijar
# Processing Record 6 of Set 3 | zhangye
# Processing Record 7 of Set 3 | sao filipe
# Processing Record 8 of Set 3 | yar-sale
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | innisfail
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | morant bay
# Processing Record 13 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 3 | sorong
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | sakakah
# Processing Record 18 of Set 3 | marawi
# Processing Record 19 of Set 3 | uspenka
# Processing Record 20 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 3 | najran
# Processing Record 22 of Set 3 | west odessa
# Processing Record 23 of Set 3 | kysyl-syr
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | port elizabeth
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | matagami
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | petersberg
# Processing Record 31 of Set 3 | batobalani
# Processing Record 32 of Set 3 | guerrero negro
# Processing Record 33 of Set 3 | siuna
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | zabol
# Processing Record 39 of Set 3 | grootfontein
# Processing Record 40 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | mandiana
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | villa altagracia
# Processing Record 47 of Set 3 | flinders
# Processing Record 48 of Set 3 | cape town
# Processing Record 49 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 3 | swan hill
# Processing Record 1 of Set 4 | ndola
# Processing Record 2 of Set 4 | sirnak
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | kupang
# Processing Record 5 of Set 4 | netishyn
# Processing Record 6 of Set 4 | kaitangata
# Processing Record 7 of Set 4 | hoquiam
# Processing Record 8 of Set 4 | tara
# Processing Record 9 of Set 4 | poso
# Processing Record 10 of Set 4 | caramay
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | novyy buh
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | gazanjyk
# Processing Record 15 of Set 4 | avera
# Processing Record 16 of Set 4 | praia da vitoria
# Processing Record 17 of Set 4 | xinzhi
# Processing Record 18 of Set 4 | muslyumovo
# Processing Record 19 of Set 4 | belyy yar
# Processing Record 20 of Set 4 | emirdag
# Processing Record 21 of Set 4 | maltahohe
# Processing Record 22 of Set 4 | punta de bombon
# Processing Record 23 of Set 4 | luganville
# Processing Record 24 of Set 4 | kavieng
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | gornopravdinsk
# Processing Record 27 of Set 4 | ndago
# Processing Record 28 of Set 4 | mount gambier
# Processing Record 29 of Set 4 | jerusalem
# Processing Record 30 of Set 4 | fairbanks
# Processing Record 31 of Set 4 | romitan
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | ananas
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | ballitoville
# Processing Record 37 of Set 4 | cao bang
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | geraldton
# Processing Record 40 of Set 4 | los llanos de aridane
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | morondava
# Processing Record 43 of Set 4 | nome
# Processing Record 44 of Set 4 | eureka
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | chabahar
# Processing Record 47 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 4 | hovd
# Processing Record 49 of Set 4 | airai
# Processing Record 50 of Set 4 | san quintin
# Processing Record 1 of Set 5 | sangolqui
# Processing Record 2 of Set 5 | vostok
# Processing Record 3 of Set 5 | mount pleasant
# Processing Record 4 of Set 5 | provideniya
# Processing Record 5 of Set 5 | saint-leu
# Processing Record 6 of Set 5 | namibe
# Processing Record 7 of Set 5 | russkaya polyana
# Processing Record 8 of Set 5 | filingue
# Processing Record 9 of Set 5 | klaksvik
# Processing Record 10 of Set 5 | eldorado
# Processing Record 11 of Set 5 | preobrazheniye
# Processing Record 12 of Set 5 | kirakira
# Processing Record 13 of Set 5 | rawson
# Processing Record 14 of Set 5 | beisfjord
# Processing Record 15 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | mendahara
# City not found. Skipping...
# Processing Record 19 of Set 5 | liverpool
# Processing Record 20 of Set 5 | brae
# Processing Record 21 of Set 5 | san carlos de bariloche
# Processing Record 22 of Set 5 | sembe
# Processing Record 23 of Set 5 | rudnogorsk
# Processing Record 24 of Set 5 | katsuyama
# Processing Record 25 of Set 5 | padang
# Processing Record 26 of Set 5 | hamilton
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | lima
# Processing Record 29 of Set 5 | salalah
# Processing Record 30 of Set 5 | acarau
# Processing Record 31 of Set 5 | cockburn town
# Processing Record 32 of Set 5 | port augusta
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | yamada
# Processing Record 35 of Set 5 | ust-tsilma
# Processing Record 36 of Set 5 | kulhudhuffushi
# Processing Record 37 of Set 5 | talnakh
# Processing Record 38 of Set 5 | middelburg
# Processing Record 39 of Set 5 | saint anthony
# Processing Record 40 of Set 5 | necochea
# Processing Record 41 of Set 5 | narrabri
# Processing Record 42 of Set 5 | kapit
# Processing Record 43 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 5 | odweyne
# Processing Record 45 of Set 5 | mayo
# Processing Record 46 of Set 5 | bonavista
# Processing Record 47 of Set 5 | brigantine
# Processing Record 48 of Set 5 | krasnyy chikoy
# Processing Record 49 of Set 5 | methven
# Processing Record 50 of Set 5 | haimen
# Processing Record 1 of Set 6 | bowen
# Processing Record 2 of Set 6 | hirara
# Processing Record 3 of Set 6 | akyab
# Processing Record 4 of Set 6 | takoradi
# Processing Record 5 of Set 6 | veraval
# Processing Record 6 of Set 6 | chimbote
# Processing Record 7 of Set 6 | sterling
# Processing Record 8 of Set 6 | llanes
# Processing Record 9 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 6 | anloga
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | porto novo
# Processing Record 15 of Set 6 | rocha
# Processing Record 16 of Set 6 | sabha
# Processing Record 17 of Set 6 | lundazi
# Processing Record 18 of Set 6 | lagoa
# Processing Record 19 of Set 6 | sisimiut
# Processing Record 20 of Set 6 | abilene
# Processing Record 21 of Set 6 | playas
# Processing Record 22 of Set 6 | borogontsy
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | bambanglipuro
# Processing Record 25 of Set 6 | diksmuide
# Processing Record 26 of Set 6 | santa isabel
# Processing Record 27 of Set 6 | kidal
# Processing Record 28 of Set 6 | faanui
# Processing Record 29 of Set 6 | meulaboh
# Processing Record 30 of Set 6 | norman wells
# Processing Record 31 of Set 6 | sept-iles
# Processing Record 32 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 33 of Set 6 | roald
# Processing Record 34 of Set 6 | lipin bor
# Processing Record 35 of Set 6 | hommelvik
# Processing Record 36 of Set 6 | hare bay
# Processing Record 37 of Set 6 | zhuanghe
# Processing Record 38 of Set 6 | lebu
# Processing Record 39 of Set 6 | sentjur
# Processing Record 40 of Set 6 | corinto
# Processing Record 41 of Set 6 | luderitz
# Processing Record 42 of Set 6 | vao
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | saint-joseph
# Processing Record 45 of Set 6 | torbay
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | solaro
# Processing Record 48 of Set 6 | mar del plata
# Processing Record 49 of Set 6 | chitral
# Processing Record 50 of Set 6 | garden city
# Processing Record 1 of Set 7 | inta
# Processing Record 2 of Set 7 | birmitrapur
# Processing Record 3 of Set 7 | cap-aux-meules
# Processing Record 4 of Set 7 | provost
# Processing Record 5 of Set 7 | ozubulu
# Processing Record 6 of Set 7 | tari
# Processing Record 7 of Set 7 | westport
# Processing Record 8 of Set 7 | ilo
# Processing Record 9 of Set 7 | canto do buriti
# Processing Record 10 of Set 7 | norrtalje
# Processing Record 11 of Set 7 | asau
# Processing Record 12 of Set 7 | nelson bay
# Processing Record 13 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 14 of Set 7 | moranbah
# Processing Record 15 of Set 7 | santa rosa
# Processing Record 16 of Set 7 | ternate
# Processing Record 17 of Set 7 | aracati
# Processing Record 18 of Set 7 | igrim
# Processing Record 19 of Set 7 | siniscola
# Processing Record 20 of Set 7 | beringovskiy
# Processing Record 21 of Set 7 | talaya
# Processing Record 22 of Set 7 | along
# Processing Record 23 of Set 7 | nemuro
# Processing Record 24 of Set 7 | bereda
# Processing Record 25 of Set 7 | ahipara
# Processing Record 26 of Set 7 | kennett
# Processing Record 27 of Set 7 | zhezkazgan
# Processing Record 28 of Set 7 | terney
# Processing Record 29 of Set 7 | robertsport
# Processing Record 30 of Set 7 | jerantut
# Processing Record 31 of Set 7 | nantucket
# Processing Record 32 of Set 7 | great yarmouth
# Processing Record 33 of Set 7 | longyearbyen
# Processing Record 34 of Set 7 | roma
# Processing Record 35 of Set 7 | leh
# Processing Record 36 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 37 of Set 7 | grindavik
# Processing Record 38 of Set 7 | bambous virieux
# Processing Record 39 of Set 7 | mantua
# Processing Record 40 of Set 7 | jijiga
# Processing Record 41 of Set 7 | shache
# Processing Record 42 of Set 7 | hilo
# Processing Record 43 of Set 7 | mitsamiouli
# Processing Record 44 of Set 7 | kilindoni
# Processing Record 45 of Set 7 | beloha
# Processing Record 46 of Set 7 | umm lajj
# Processing Record 47 of Set 7 | comodoro rivadavia
# Processing Record 48 of Set 7 | san rafael
# Processing Record 49 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 7 | touros
# Processing Record 1 of Set 8 | ixtapa
# Processing Record 2 of Set 8 | san policarpo
# Processing Record 3 of Set 8 | vila velha
# Processing Record 4 of Set 8 | premia de mar
# Processing Record 5 of Set 8 | gizo
# Processing Record 6 of Set 8 | wanaka
# Processing Record 7 of Set 8 | lenine
# Processing Record 8 of Set 8 | moctezuma
# Processing Record 9 of Set 8 | sayyan
# Processing Record 10 of Set 8 | filadelfia
# Processing Record 11 of Set 8 | karlovac
# Processing Record 12 of Set 8 | kihei
# Processing Record 13 of Set 8 | viljoenskroon
# Processing Record 14 of Set 8 | araguaina
# Processing Record 15 of Set 8 | puerto leguizamo
# Processing Record 16 of Set 8 | maceio
# Processing Record 17 of Set 8 | areosa
# Processing Record 18 of Set 8 | el dorado
# Processing Record 19 of Set 8 | skagen
# Processing Record 20 of Set 8 | matay
# Processing Record 21 of Set 8 | medvezhyegorsk
# Processing Record 22 of Set 8 | hermosillo
# Processing Record 23 of Set 8 | manta
# Processing Record 24 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 8 | lorengau
# Processing Record 26 of Set 8 | yulara
# Processing Record 27 of Set 8 | melivoia
# Processing Record 28 of Set 8 | pisco
# Processing Record 29 of Set 8 | college
# Processing Record 30 of Set 8 | biltine
# Processing Record 31 of Set 8 | zapolyarnyy
# Processing Record 32 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 8 | tortoli
# Processing Record 34 of Set 8 | tema
# Processing Record 35 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 8 | muisne
# Processing Record 37 of Set 8 | porto nacional
# Processing Record 38 of Set 8 | jaramana
# City not found. Skipping...
# Processing Record 39 of Set 8 | villa san giovanni
# Processing Record 40 of Set 8 | pinawa
# Processing Record 41 of Set 8 | portland
# Processing Record 42 of Set 8 | mount isa
# Processing Record 43 of Set 8 | gravelbourg
# Processing Record 44 of Set 8 | kruisfontein
# Processing Record 45 of Set 8 | hun
# Processing Record 46 of Set 8 | baloda bazar
# Processing Record 47 of Set 8 | pemba
# Processing Record 48 of Set 8 | ostersund
# Processing Record 49 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 50 of Set 8 | eydhafushi
# Processing Record 1 of Set 9 | olafsvik
# Processing Record 2 of Set 9 | adrar
# Processing Record 3 of Set 9 | verkhoturye
# Processing Record 4 of Set 9 | itoman
# Processing Record 5 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 9 | anadyr
# Processing Record 7 of Set 9 | never
# Processing Record 8 of Set 9 | kieta
# Processing Record 9 of Set 9 | barinas
# Processing Record 10 of Set 9 | hambantota
# Processing Record 11 of Set 9 | danville
# Processing Record 12 of Set 9 | kismayo
# Processing Record 13 of Set 9 | karratha
# Processing Record 14 of Set 9 | choix
# Processing Record 15 of Set 9 | praia
# Processing Record 16 of Set 9 | dukat
# Processing Record 17 of Set 9 | tura
# Processing Record 18 of Set 9 | athabasca
# Processing Record 19 of Set 9 | iracoubo
# Processing Record 20 of Set 9 | grand gaube
# Processing Record 21 of Set 9 | chicama
# Processing Record 22 of Set 9 | nishihara
# Processing Record 23 of Set 9 | rivarolo canavese
# Processing Record 24 of Set 9 | panaba
# Processing Record 25 of Set 9 | hobyo
# Processing Record 26 of Set 9 | sivaki
# Processing Record 27 of Set 9 | pereslavl-zalesskiy
# Processing Record 28 of Set 9 | kristiinankaupunki
# Processing Record 29 of Set 9 | salta
# Processing Record 30 of Set 9 | khonsa
# Processing Record 31 of Set 9 | socorro
# Processing Record 32 of Set 9 | nador
# Processing Record 33 of Set 9 | ancud
# Processing Record 34 of Set 9 | itarema
# Processing Record 35 of Set 9 | caravelas
# Processing Record 36 of Set 9 | jalu
# Processing Record 37 of Set 9 | killybegs
# Processing Record 38 of Set 9 | kamenka
# Processing Record 39 of Set 9 | kiunga
# Processing Record 40 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 41 of Set 9 | lahat
# Processing Record 42 of Set 9 | sweetwater
# Processing Record 43 of Set 9 | ustye
# Processing Record 44 of Set 9 | zharkent
# Processing Record 45 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 9 | paamiut
# Processing Record 47 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 48 of Set 9 | ajdabiya
# Processing Record 49 of Set 9 | nicoya
# Processing Record 50 of Set 9 | taoudenni
# Processing Record 1 of Set 10 | dunmore town
# Processing Record 2 of Set 10 | havelock
# Processing Record 3 of Set 10 | klishkivtsi
# Processing Record 4 of Set 10 | kommunisticheskiy
# Processing Record 5 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 10 | sinop
# Processing Record 7 of Set 10 | alice springs
# Processing Record 8 of Set 10 | oranjemund
# Processing Record 9 of Set 10 | ondangwa
# Processing Record 10 of Set 10 | talcahuano
# Processing Record 11 of Set 10 | husavik
# Processing Record 12 of Set 10 | mahebourg
# Processing Record 13 of Set 10 | nikolskoye
# Processing Record 14 of Set 10 | dvinskoy
# Processing Record 15 of Set 10 | kouroussa
# Processing Record 16 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 17 of Set 10 | cairns
# Processing Record 18 of Set 10 | saint-philippe
# Processing Record 19 of Set 10 | burgeo
# Processing Record 20 of Set 10 | sangar
# Processing Record 21 of Set 10 | port said
# Processing Record 22 of Set 10 | okha
# Processing Record 23 of Set 10 | udachnyy
# Processing Record 24 of Set 10 | aripuana
# Processing Record 25 of Set 10 | dovers
# Processing Record 26 of Set 10 | henties bay
# Processing Record 27 of Set 10 | moose factory
# Processing Record 28 of Set 10 | salina
# Processing Record 29 of Set 10 | sibu
# Processing Record 30 of Set 10 | port hedland
# Processing Record 31 of Set 10 | llangefni
# Processing Record 32 of Set 10 | aguimes
# Processing Record 33 of Set 10 | kharan
# Processing Record 34 of Set 10 | ramsar
# Processing Record 35 of Set 10 | mareeba
# Processing Record 36 of Set 10 | la ronge
# Processing Record 37 of Set 10 | mahenge
# Processing Record 38 of Set 10 | tilichiki
# Processing Record 39 of Set 10 | tyup
# Processing Record 40 of Set 10 | narsaq
# Processing Record 41 of Set 10 | pueblo nuevo
# Processing Record 42 of Set 10 | camacha
# Processing Record 43 of Set 10 | kushima
# Processing Record 44 of Set 10 | abu samrah
# Processing Record 45 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | san andres
# Processing Record 47 of Set 10 | barcelona
# Processing Record 48 of Set 10 | te anau
# Processing Record 49 of Set 10 | saint-germain-de-grantham
# Processing Record 50 of Set 10 | dashitou
# Processing Record 1 of Set 11 | luoyang
# Processing Record 2 of Set 11 | kedrovyy
# Processing Record 3 of Set 11 | rumonge
# Processing Record 4 of Set 11 | port blair
# Processing Record 5 of Set 11 | basco
# Processing Record 6 of Set 11 | hoa binh
# Processing Record 7 of Set 11 | port pirie
# Processing Record 8 of Set 11 | rognan
# Processing Record 9 of Set 11 | dover
# Processing Record 10 of Set 11 | catamarca
# Processing Record 11 of Set 11 | lavrentiya
# Processing Record 12 of Set 11 | aktau
# Processing Record 13 of Set 11 | zhigalovo
# Processing Record 14 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 15 of Set 11 | auki
# Processing Record 16 of Set 11 | sundumbili
# Processing Record 17 of Set 11 | lerwick
# Processing Record 18 of Set 11 | topeka
# Processing Record 19 of Set 11 | miri
# Processing Record 20 of Set 11 | oistins
# Processing Record 21 of Set 11 | capinota
# Processing Record 22 of Set 11 | joniskis
# Processing Record 23 of Set 11 | sampang
# Processing Record 24 of Set 11 | pangnirtung
# Processing Record 25 of Set 11 | bull savanna
# Processing Record 26 of Set 11 | bonthe
# Processing Record 27 of Set 11 | pimentel
# Processing Record 28 of Set 11 | oriximina
# Processing Record 29 of Set 11 | adre
# Processing Record 30 of Set 11 | vanavara
# Processing Record 31 of Set 11 | pontal do parana
# Processing Record 32 of Set 11 | komsomolskiy
# Processing Record 33 of Set 11 | svobodnyy
# Processing Record 34 of Set 11 | san cristobal
# Processing Record 35 of Set 11 | soe
# Processing Record 36 of Set 11 | fort nelson
# Processing Record 37 of Set 11 | sorland
# Processing Record 38 of Set 11 | kibakwe
# Processing Record 39 of Set 11 | sungairaya
# Processing Record 40 of Set 11 | brigham city
# Processing Record 41 of Set 11 | ilulissat
# Processing Record 42 of Set 11 | kununurra
# Processing Record 43 of Set 11 | tabou
# Processing Record 44 of Set 11 | puerto colombia
# Processing Record 45 of Set 11 | christchurch
# Processing Record 46 of Set 11 | dwarka
# Processing Record 47 of Set 11 | rio gallegos
# Processing Record 48 of Set 11 | moree
# Processing Record 49 of Set 11 | lakselv
# Processing Record 50 of Set 11 | gondanglegi
# Processing Record 1 of Set 12 | uricani
# Processing Record 2 of Set 12 | kemerovo
# Processing Record 3 of Set 12 | bandar-e lengeh
# Processing Record 4 of Set 12 | sao joao da barra
# Processing Record 5 of Set 12 | broome
# Processing Record 6 of Set 12 | baft
# Processing Record 7 of Set 12 | olinda
# Processing Record 8 of Set 12 | yarensk
# Processing Record 9 of Set 12 | sao gabriel da cachoeira
# Processing Record 10 of Set 12 | ilhabela
# Processing Record 11 of Set 12 | forrest city
# Processing Record 12 of Set 12 | turukhansk
# Processing Record 13 of Set 12 | sulphur
# Processing Record 14 of Set 12 | uvalde
# Processing Record 15 of Set 12 | haapiti
# Processing Record 16 of Set 12 | batemans bay
# Processing Record 17 of Set 12 | saint-pierre
# Processing Record 18 of Set 12 | januaria
# Processing Record 19 of Set 12 | palmer
# Processing Record 20 of Set 12 | oga
# Processing Record 21 of Set 12 | ketchikan
# Processing Record 22 of Set 12 | kayankulam
# Processing Record 23 of Set 12 | atbasar
# Processing Record 24 of Set 12 | ende
# Processing Record 25 of Set 12 | rio cuarto
# Processing Record 26 of Set 12 | khani
# Processing Record 27 of Set 12 | berdigestyakh
# Processing Record 28 of Set 12 | weiser
# Processing Record 29 of Set 12 | krasnoselkup
# Processing Record 30 of Set 12 | anito
# Processing Record 31 of Set 12 | ocos
# Processing Record 32 of Set 12 | gaya
# Processing Record 33 of Set 12 | alofi
# Processing Record 34 of Set 12 | waipawa
# Processing Record 35 of Set 12 | banepa
# Processing Record 36 of Set 12 | kearney
# Processing Record 37 of Set 12 | salinopolis
# Processing Record 38 of Set 12 | karpathos
# Processing Record 39 of Set 12 | berlevag
# Processing Record 40 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 41 of Set 12 | laguna
# Processing Record 42 of Set 12 | cobija
# Processing Record 43 of Set 12 | goma
# Processing Record 44 of Set 12 | fiumicino
# Processing Record 45 of Set 12 | kailua
# Processing Record 46 of Set 12 | pyaozerskiy
# Processing Record 47 of Set 12 | belogorsk
# Processing Record 48 of Set 12 | chanika
# Processing Record 49 of Set 12 | sinnamary
# Processing Record 50 of Set 12 | machinga
# Processing Record 1 of Set 13 | jacksonville
# Processing Record 2 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 13 | yakeshi
# Processing Record 4 of Set 13 | gonda
# Processing Record 5 of Set 13 | yarmouth
# Processing Record 6 of Set 13 | georgiyevka
# Processing Record 7 of Set 13 | buraydah
# Processing Record 8 of Set 13 | starokamyshinsk
# Processing Record 9 of Set 13 | harper
# Processing Record 10 of Set 13 | kabinda
# Processing Record 11 of Set 13 | korla
# Processing Record 12 of Set 13 | amapa
# Processing Record 13 of Set 13 | yantongshan
# Processing Record 14 of Set 13 | zwedru
# Processing Record 15 of Set 13 | tarakan
# Processing Record 16 of Set 13 | iqaluit
# Processing Record 17 of Set 13 | miramar
# Processing Record 18 of Set 13 | lakes entrance
# Processing Record 19 of Set 13 | beckley
# Processing Record 20 of Set 13 | barra do corda
# Processing Record 21 of Set 13 | mokolo
# Processing Record 22 of Set 13 | verkhnyachka
# Processing Record 23 of Set 13 | neftegorsk
# Processing Record 24 of Set 13 | sembakung
# Processing Record 25 of Set 13 | tahoua
# Processing Record 26 of Set 13 | soledade
# Processing Record 27 of Set 13 | ewa beach
# Processing Record 28 of Set 13 | luanda
# Processing Record 29 of Set 13 | saint-michel-des-saints
# Processing Record 30 of Set 13 | houston
# Processing Record 31 of Set 13 | tiznit
# Processing Record 32 of Set 13 | buchanan
# Processing Record 33 of Set 13 | sao geraldo do araguaia
# Processing Record 34 of Set 13 | ishigaki
# Processing Record 35 of Set 13 | lasa
# Processing Record 36 of Set 13 | taltal
# Processing Record 37 of Set 13 | dauriya
# Processing Record 38 of Set 13 | pingliang
# Processing Record 39 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 13 | carroll
# Processing Record 42 of Set 13 | san jeronimo
# Processing Record 43 of Set 13 | lamu
# Processing Record 44 of Set 13 | haines junction
# Processing Record 45 of Set 13 | payson
# Processing Record 46 of Set 13 | the valley
# Processing Record 47 of Set 13 | faya
# Processing Record 48 of Set 13 | pundaguitan
# Processing Record 49 of Set 13 | upington
# Processing Record 50 of Set 13 | matoury
# Processing Record 1 of Set 14 | sao francisco
# Processing Record 2 of Set 14 | tommot
# Processing Record 3 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 14 | tahe
# Processing Record 5 of Set 14 | vestmannaeyjar
# Processing Record 6 of Set 14 | hofn
# Processing Record 7 of Set 14 | shubarshi
# Processing Record 8 of Set 14 | pacific grove
# Processing Record 9 of Set 14 | wakema
# Processing Record 10 of Set 14 | nuuk
# Processing Record 11 of Set 14 | ariquemes
# Processing Record 12 of Set 14 | poum
# Processing Record 13 of Set 14 | gardelegen
# Processing Record 14 of Set 14 | olga
# Processing Record 15 of Set 14 | cheney
# Processing Record 16 of Set 14 | mecca
# Processing Record 17 of Set 14 | hameenlinna
# Processing Record 18 of Set 14 | fukue
# Processing Record 19 of Set 14 | faranah
# Processing Record 20 of Set 14 | lyuban
# Processing Record 21 of Set 14 | miranda
# Processing Record 22 of Set 14 | rosarito
# Processing Record 23 of Set 14 | betioky
# Processing Record 24 of Set 14 | savonlinna
# Processing Record 25 of Set 14 | malakal
# Processing Record 26 of Set 14 | qaqortoq
# Processing Record 27 of Set 14 | ngunguru
# Processing Record 28 of Set 14 | puri
# Processing Record 29 of Set 14 | oktyabrskoye
# Processing Record 30 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 14 | mendi
# Processing Record 32 of Set 14 | sovetskiy
# Processing Record 33 of Set 14 | kropotkin
# Processing Record 34 of Set 14 | toamasina
# Processing Record 35 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 14 | barra patuca
# Processing Record 37 of Set 14 | verkhoyansk
# Processing Record 38 of Set 14 | zdvinsk
# Processing Record 39 of Set 14 | inhambane
# Processing Record 40 of Set 14 | kani
# Processing Record 41 of Set 14 | villaviciosa
# Processing Record 42 of Set 14 | plouzane
# Processing Record 43 of Set 14 | kalmunai
# Processing Record 44 of Set 14 | caconda
# Processing Record 45 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 14 | mangan
# Processing Record 47 of Set 14 | fortuna
# Processing Record 48 of Set 14 | margate
# Processing Record 49 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 50 of Set 14 | gat
# Processing Record 1 of Set 15 | victor harbor
# Processing Record 2 of Set 15 | agadez
# Processing Record 3 of Set 15 | bubaque
# Processing Record 4 of Set 15 | fort abbas
# Processing Record 5 of Set 15 | banjar
# Processing Record 6 of Set 15 | valdivia
# Processing Record 7 of Set 15 | kushikino
# Processing Record 8 of Set 15 | rio grande
# Processing Record 9 of Set 15 | abbeville
# Processing Record 10 of Set 15 | maumere
# Processing Record 11 of Set 15 | thunder bay
# Processing Record 12 of Set 15 | omsukchan
# Processing Record 13 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 15 | pittsburg
# Processing Record 15 of Set 15 | dole
# Processing Record 16 of Set 15 | traverse city
# Processing Record 17 of Set 15 | puerto baquerizo moreno
# Processing Record 18 of Set 15 | ust-kuyga
# Processing Record 19 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 15 | meadow lake
# Processing Record 21 of Set 15 | paita
# Processing Record 22 of Set 15 | chapada dos guimaraes
# Processing Record 23 of Set 15 | terrasini
# Processing Record 24 of Set 15 | truth or consequences
# Processing Record 25 of Set 15 | kisangani
# Processing Record 26 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 27 of Set 15 | sapele
# Processing Record 28 of Set 15 | borba
# Processing Record 29 of Set 15 | hearst
# Processing Record 30 of Set 15 | vagur
# Processing Record 31 of Set 15 | ostrovnoy
# Processing Record 32 of Set 15 | wajima
# Processing Record 33 of Set 15 | balakirevo
# Processing Record 34 of Set 15 | xining
# Processing Record 35 of Set 15 | havre-saint-pierre
# Processing Record 36 of Set 15 | kloulklubed
# Processing Record 37 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 15 | guarapari
# Processing Record 39 of Set 15 | kingsport
# Processing Record 40 of Set 15 | diamantino
# Processing Record 41 of Set 15 | florianopolis
# Processing Record 42 of Set 15 | talara
# Processing Record 43 of Set 15 | doha
# Processing Record 44 of Set 15 | aguas vermelhas
# Processing Record 45 of Set 15 | bone
# Processing Record 46 of Set 15 | gorontalo
# Processing Record 47 of Set 15 | malpe
# Processing Record 48 of Set 15 | slave lake
# Processing Record 49 of Set 15 | zeya
# Processing Record 50 of Set 15 | pilar
# Processing Record 1 of Set 16 | bandarbeyla
# Processing Record 2 of Set 16 | raga
# Processing Record 3 of Set 16 | kamloops
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Leningradskiy  69.3833  178.4167     -0.17        94         100
# 1   Puerto Ayora  -0.7393  -90.3518     75.99        95          68
# 2       Goderich  43.7501  -81.7165     41.00        56           3
# 3     Bokovskaya  49.2290   41.8306     38.93        70          89
# 4   Punta Arenas -53.1500  -70.9167     39.20        70           0
# 5        El Alto  -4.2714  -81.2147     70.83        83          94
# 6       Victoria  22.2855  114.1577     80.01        85          29
# 7        Ushuaia -54.8000  -68.3000     35.60        75          40
# 8          Dubbo -32.2500  148.6167     80.60        41          40
# 9      Jamestown  42.0970  -79.2353     46.00        36          90
#
#    Wind Speed Country                 Date       Description
# 0        7.31      RU  2021-04-04 04:53:47   overcast clouds
# 1        1.99      EC  2021-04-04 04:53:47     broken clouds
# 2        6.91      CA  2021-04-04 04:53:47         clear sky
# 3        8.66      RU  2021-04-04 04:53:48   overcast clouds
# 4       11.50      CL  2021-04-04 04:53:35         clear sky
# 5        7.47      PE  2021-04-04 04:53:48        light rain
# 6        1.01      HK  2021-04-04 04:52:53  scattered clouds
# 7        4.61      AR  2021-04-04 04:42:06  scattered clouds
# 8        4.61      AU  2021-04-04 04:53:49  scattered clouds
# 9        9.22      US  2021-04-04 04:44:12   overcast clouds

# %%
city_data_new_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']

# %%
city_data_df = city_data_df[city_data_new_order]
city_data_df.head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0  Leningradskiy      RU  2021-04-04 04:53:47  69.3833  178.4167     -0.17
# 1   Puerto Ayora      EC  2021-04-04 04:53:47  -0.7393  -90.3518     75.99
# 2       Goderich      CA  2021-04-04 04:53:47  43.7501  -81.7165     41.00
# 3     Bokovskaya      RU  2021-04-04 04:53:48  49.2290   41.8306     38.93
# 4   Punta Arenas      CL  2021-04-04 04:53:35 -53.1500  -70.9167     39.20
#
#    Humidity  Cloudiness  Wind Speed      Description
# 0        94         100        7.31  overcast clouds
# 1        95          68        1.99    broken clouds
# 2        56           3        6.91        clear sky
# 3        70          89        8.66  overcast clouds
# 4        70           0       11.50        clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
